# %%
from course_utils.paths import get_project_root, get_data_dir

print("프로젝트 루트 :", get_project_root())
print("데이터 폴더 :", get_data_dir())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from course_utils.paths import get_project_root, get_data_dir
#       2
#       3 print("프로젝트 루트 :", get_project_root())
#       4 print("데이터 폴더 :", get_data_dir())
#
# ModuleNotFoundError: No module named 'course_utils'

# %%
import pandas as pd

orders = pd.read_csv("../../data/raw/orders.csv")

orders.head()
# Out:
#    order_id  customer_id  order_date payment_method order_status
# 0         1          123  2026-07-02           card    completed
# 1         2           77  2025-09-17      naver_pay    cancelled
# 2         3          138  2026-01-14  bank_transfer    cancelled
# 3         4           57  2026-03-27      kakao_pay    cancelled
# 4         5          125  2026-02-15           card    cancelled

# %%
# 주문 상태의 종류는 몇가지이고 각 상태별 주문 수량?
ret = orders["order_status"].value_counts(dropna = False)
print(type(ret))
print(ret)
# 결제 수단의 종류는 몇가지이고 각 결제 상태별 주문수량?
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # 주문 상태의 종류는 몇가지이고 각 상태별 주문 수량?
# ----> 2 ret = orders["order_status"].value_counts(dropna = False)
#       3 print(type(ret))
#       4 print(ret)
#       5 # 결제 수단의 종류는 몇가지이고 각 결제 상태별 주문수량?
#
# NameError: name 'orders' is not defined

# %%
# customers_over_30
customers_over_30 = customers[customers["age"] >= 30]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 # customers_over_30
# ----> 2 customers_over_30 = customers[customers["age"] >= 30]
#
# NameError: name 'customers' is not defined
